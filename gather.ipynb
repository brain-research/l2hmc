# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = {}
test = {}

for f in os.listdir('logs/09-21'):
    train_path = 'logs/09-21/%s/train_ll.txt' % f
    test_path = 'logs/09-21/%s/test_ll.txt' % f
    if not os.path.isfile(train_path) or not os.path.isfile(test_path):
        continue
    with open(train_path) as g:
        train[f] = str(g.readline())
    with open(test_path) as g:
        test[f] = str(g.readline())

# %%
train_HMC = [-84.45, -83.12, -82.54, -81.94]
train_CS = [-85.87, -83.08, -83.06, -84.45]

# %%
train
# Out:
# {'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=10,batch_size=512,update_sampler_every=1,leapfrogs=10,hmc=True': '-82.0014660645',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=10,batch_size=512,update_sampler_every=1,leapfrogs=2,hmc=False': '-87.0467675781',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=10,batch_size=512,update_sampler_every=1,leapfrogs=5,hmc=False': '-83.7826269531',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=10,batch_size=512,update_sampler_every=1,leapfrogs=5,hmc=True': '-81.94',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=10,hmc=False': '-82.7460083008',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=10,hmc=True': '-82.74',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=2,hmc=False': '-84.7865673828',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=2,hmc=True': '-83.1660058594',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=5,hmc=False': '-82.8123522949',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=2,batch_size=512,update_sampler_every=1,leapfrogs=5,hmc=True': '-83.12',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=5,batch_size=512,update_sampler_every=1,leapfrogs=10,hmc=True': '-82.4070336914',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=5,batch_size=512,update_sampler_every=1,leapfrogs=2,hmc=False': '-86.0033886719',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=5,batch_size=512,update_sampler_every=1,leapfrogs=2,hmc=True': 'nan',
#  'optimizer=adam,learning_rate=0.001,latent_dim=50,MH=5,batch_size=512,update_sampler_every=1,leapfrogs=5,hmc=True': '-82.54'}

# %%
plt.plot(lf, train_HMC, marker='d', label='HMC')
plt.plot(lf, train_CS, marker='d', label='CS')
plt.xlabel('# LF')
plt.ylabel('LL')
plt.title('Train set')
plt.legend()

# %%
test_CS = [-87.62, -85.73, -85.91, -87.35]
test_MH = [-88.40, -85.81, -85.19, -84.84]

# %%
plt.plot(lf, test_MH, marker='d', label='HMC')
plt.plot(lf, test_CS, marker='d', label='CS')
plt.xlabel('# LF')
plt.ylabel('LL')
plt.title('Test set')
plt.legend()

# %%
lf = [1, 2, 5, 10]
